# %%
# !jupyter nbconvert --to script twt_data_30days.ipynb

# !jupyter nbconvert --to script aggregate_data.ipynb

# !jupyter nbconvert --to script tweet_sentiment.ipynb
# Out:
# [NbConvertApp] Converting notebook twt_data_30days.ipynb to script
# [NbConvertApp] Writing 3462 bytes to twt_data_30days.py
# [NbConvertApp] Converting notebook aggregate_data.ipynb to script
# [NbConvertApp] Writing 5519 bytes to aggregate_data.py
# [NbConvertApp] Converting notebook tweet_sentiment.ipynb to script
# [NbConvertApp] Writing 5071 bytes to tweet_sentiment.py

# %%
#import twt_data_30days as twtdata
import aggregate_data as aggd
import tweet_sentiment as sent
# Out:
# /home/rmh/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# [nltk_data] Downloading package stopwords to /home/rmh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#twtdata.get_twt_data_today()

# %%
aggd.agg_all()

# %%
sent.generate_all_sentiments()
# Out:
# ---- candidate ------
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# ---- economy ------
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# ---- party ------
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# ---- environment ------
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# ---- health ------
# 1000
# ...
